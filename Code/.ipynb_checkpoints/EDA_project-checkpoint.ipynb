# %%
import lucem_illud_2020 #pip install -U git+git://github.com/Computational-Content-Analysis-2020/lucem_illud_2020.git
import scipy #For hierarchical clustering and some visuals
#import scipy.cluster.hierarchy
import gensim#For topic modeling
import requests #For downloading our datasets
import numpy as np #for arrays
import pandas as pd #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import matplotlib.cm #Still for graphics
import seaborn as sns #Makes the graphics look nicer

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning, it
# %matplotlib inline

import itertools
import json

# comp-linguistics
import scipy
import spacy
import en_core_web_sm
import nltk

import warnings
warnings.filterwarnings('ignore')

import random
random.seed(2020)

# %% [markdown]
# ### Loading and Cleaning the data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/liu431/Content-Analysis-Project/master/Data/output_review.csv")
df_meta = pd.read_csv("https://raw.githubusercontent.com/liu431/Content-Analysis-Project/master/Data/output_meta.csv")
df.shape
# Out:
# (5511, 14)

# %%
df_meta
# Out:
#    Unnamed: 0  overall        asin  \
# 0          92     2567  B000A6PPOK
# 1         191     1805  B00I0S6SK0
# 2        2263      418  B00E4TOWR0
# 3        2620      378  B00LSGKEC4
# 4        2962      343  B0194MC7JG
#
#                                             category  \
# 0  ['Electronics', 'Computers & Accessories', 'Co...
# 1  ['Electronics', 'Computers & Accessories', 'Co...
# 2  ['Electronics', 'Computers & Accessories', 'Co...
# 3  ['Electronics', 'Computers & Accessories', 'Co...
# 4  ['Electronics', 'Computers & Accessories', 'Co...
#
#                                          description  \
# 0                                            ['USB']
# 1  ['The AZiO Vision keyboard features extra larg...
# 2  ["Get-more-done productivity: Achieve more wit...
# 3                                                NaN
# 4  ['ONE WIRELESS KEYBOARD AND MOUSE SET FOR WIRE...
#
#                                                title  \
# 0          Microsoft Natural Ergonomic Keyboard 4000
# 1  Azio Vision Backlit USB Keyboard with Large Pr...
# 2  HP Wired USB Keyboard K1500 (Black) (H3C52AA#ABA)
# 3  Redragon K502 Gaming Keyboard RGB LED Backlit ...
# 4  Wireless Keyboard and Mouse - Jelly Comb K025 ...
#
#                                                image       brand  \
# 0  ['https://images-na.ssl-images-amazon.com/imag...   Microsoft
# 1  ['https://images-na.ssl-images-amazon.com/imag...        Azio
# 2  ['https://images-na.ssl-images-amazon.com/imag...          HP
# 3  ['https://images-na.ssl-images-amazon.com/imag...    Redragon
# 4  ['https://images-na.ssl-images-amazon.com/imag...  Jelly Comb
#
#                                              feature  \
# 0  ['Split ergonomic design encourages natural ha...
# 1  ['Easy to see large print keys. 2x Larger than...
# 2  ['Get-more-done productivity: Achieve more wit...
# 3  ['SILENT GAMING KEYBOARD; 104 Key Gaming Keybo...
# 4  ['RELIABLE 2.4GHz WIRELESS CONNECTION: 10m or ...
#
#                                                 rank         main_cat  \
# 0  ['>#222 in Computers & Accessories > Computer ...  All Electronics
# 1  ['>#56 in Computers & Accessories > Computer A...        Computers
# 2  ['>#25 in Computers & Accessories > Computer A...        Computers
# 3  >#263 in Computers & Accessories > Computer Ac...        Computers
# 4  ['>#323 in Computers & Accessories > Computer ...        Computers
#
#         date    price                                           also_buy  \
# 0  27-Sep-17  $48.50   ['B00FPAVUHC', 'B0043T7FXE', 'B001F42MKG', 'B0...
# 1  21-Oct-17   $2.54   ['B00ERV026K', 'B0787QZ6WD', 'B075WW7V6W', 'B0...
# 2  28-Jul-17  $14.99                                                 NaN
# 3  28-Jul-17  $28.99   ['B00HTK1NCS', 'B011HMDZ0Q', 'B00GU4F4OM', 'B0...
# 4  18-Jul-18   $2.54   ['B01B4RWTAG', 'B001CJRM36', 'B0181JTPCU', 'B0...
#
#                                            also_view  \
# 0  ['B075GZVD4T', 'B002MMY4WY', 'B00CYX26BC', 'B0...
# 1  ['B003VAGXWK', 'B00AGI7NKG', 'B007ZUC7DG', 'B0...
# 2  ['B005EOWBHC', 'B00ZYLMQH0', 'B004YDSPSS', 'B0...
# 3  ['B073DBS35C', 'B074DRFHYS', 'B01EOH2JLW', 'B0...
# 4                                                NaN
#
#                                         similar_item  \
# 0  [{'asin': '', 'href': '', 'name': 'Microsoft N...
# 1  [{'asin': '', 'href': '', 'name': 'Azio Vision...
# 2  [{'asin': '', 'href': '', 'name': 'HP Wired US...
# 3  [{'asin': '', 'href': '', 'name': 'Redragon K5...
# 4  [{'asin': '', 'href': '', 'name': 'Wireless Ke...
#
#                                                tech1  \
# 0                                                NaN
# 1                   {'Number of USB 2.0 Ports': '1'}
# 2  {'Brand Name': 'HP', 'Series': 'H3C52AA', 'Ite...
# 3  {'Brand Name': 'Redragon', 'Series': 'K502 Kar...
# 4                                                NaN
#
#                                                tech2  details  fit
# 0                                                NaN      NaN  NaN
# 1  {'Brand Name': 'Azio', 'Item model number': 'K...      NaN  NaN
# 2                                                NaN      NaN  NaN
# 3                                                NaN      NaN  NaN
# 4                                                NaN      NaN  NaN

# %%
tbl = df.groupby('asin').agg({'overall':'count'})
tbl = tbl.sort_values(by = ['overall'], ascending = False)
tbl['asin'] = tbl.index
tbl = tbl.rename_axis("ID")
tbl
# Out:
#             overall        asin
# ID
# B000A6PPOK     2567  B000A6PPOK
# B00I0S6SK0     1805  B00I0S6SK0
# B00E4TOWR0      418  B00E4TOWR0
# B00LSGKEC4      378  B00LSGKEC4
# B0194MC7JG      343  B0194MC7JG

# %% [markdown]
# We downsampled it into ~350 variables per product to make it more normally distributed among different products.

# %%
# downsampling
df_sample = df[df['asin'] == tbl.index[-1]]
for i in range(4):
    df_temp = df[df['asin'] == tbl.index[i]].sample(n=350)
    df_sample = df_sample.append(df_temp)
df_sample.shape
# Out:
# (1743, 14)

# %%
df_sample = df_sample[df_sample['reviewText'].notnull()]
df_agg = df_sample.groupby(['asin', 'title'], as_index=False)[['reviewText']].agg(sum)
df_agg
# Out:
#          asin                                              title  \
# 0  B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000
# 1  B00E4TOWR0  HP Wired USB Keyboard K1500 (Black) (H3C52AA#ABA)
# 2  B00I0S6SK0  Azio Vision Backlit USB Keyboard with Large Pr...
# 3  B00LSGKEC4  Redragon K502 Gaming Keyboard RGB LED Backlit ...
# 4  B0194MC7JG  Wireless Keyboard and Mouse - Jelly Comb K025 ...
#
#                                           reviewText
# 0  This is my all time favorite keyboard.  It fit...
# 1  On the "cheap" side, but my biggest complaint ...
# 2  I really like this keyboard. It's bright, easy...
# 3  When I switched to Mac I fell in love with Chi...
# 4  I didn't think it would be possible with this ...

# %%
df_agg['tokenized_words'] = df_agg['reviewText'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
df_agg['normalized_words'] = df_agg['tokenized_words'].apply(lambda x: lucem_illud_2020.normalizeTokens(x, lemma=False))
df_agg
# Out:
#          asin                                              title  \
# 0  B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000
# 1  B00E4TOWR0  HP Wired USB Keyboard K1500 (Black) (H3C52AA#ABA)
# 2  B00I0S6SK0  Azio Vision Backlit USB Keyboard with Large Pr...
# 3  B00LSGKEC4  Redragon K502 Gaming Keyboard RGB LED Backlit ...
# 4  B0194MC7JG  Wireless Keyboard and Mouse - Jelly Comb K025 ...
#
#                                           reviewText  \
# 0  This is my all time favorite keyboard.  It fit...
# 1  On the "cheap" side, but my biggest complaint ...
# 2  I really like this keyboard. It's bright, easy...
# 3  When I switched to Mac I fell in love with Chi...
# 4  I didn't think it would be possible with this ...
#
#                                      tokenized_words  \
# 0  [This, is, my, all, time, favorite, keyboard, ...
# 1  [On, the, cheap, side, but, my, biggest, compl...
# 2  [I, really, like, this, keyboard, It, 's, brig...
# 3  [When, I, switched, to, Mac, I, fell, in, love...
# 4  [I, did, n't, think, it, would, be, possible, ...
#
#                                     normalized_words
# 0  [time, favorite, keyboard, fits, hands, finger...
# 1  [cheap, biggest, complaint, slides, rubber, gr...
# 2  [like, keyboard, bright, easy, read, plugs, us...
# 3  [switched, mac, fell, love, chiclet, keys, swi...
# 4  [think, possible, set, ve, day, desktop, compu...

# %% [markdown]
# ## EDA

# %% [markdown]
# HW1. Counting Words

# %%
# Counting words borrowed from materials
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pd.DataFrame(countsForFrame)

# %% [markdown]
# a. Counting: Most Frequent Words (normalized)

# %%
# Aggregate to a huge list
ls_normalized_words = []
for row in df_agg.iterrows():
    ls_normalized_words += row[-1]['normalized_words']
len(ls_normalized_words)
# Out:
# 43324

# %%
df_words_count = wordCounter(ls_normalized_words)
df_words_count.sort_values('count', ascending=False, inplace=True)
df_words_count.head(10)
# Out:
#           word  count
# 2     keyboard   2333
# 41        keys   1100
# 16         key    509
# 17        like    505
# 81       great    463
# 89         use    446
# 24       mouse    348
# 95        good    338
# 682      works    280
# 179  keyboards    279

# %% [markdown]
# b. Visualization (Lexical Plot and WordCloud)

# %%
# Display results of "like", 'don't like'
ls_keyword = ['like', 'great', 'good', 'love', 'problems', 'problem', 'bad', 'poor']
sns.reset_orig() #Seaborn messes with this plot, disabling it
text.dispersion_plot(ls_keyword)
sns.set() #Re-enabling seaborn

# %%
# Word Cloud
import wordcloud
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(df_agg['normalized_words'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("song_lyrics_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# c. Sentimental Analysis

# %%
df_agg
# Out:
#          asin                                              title  \
# 0  B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000
# 1  B00E4TOWR0  HP Wired USB Keyboard K1500 (Black) (H3C52AA#ABA)
# 2  B00I0S6SK0  Azio Vision Backlit USB Keyboard with Large Pr...
# 3  B00LSGKEC4  Redragon K502 Gaming Keyboard RGB LED Backlit ...
# 4  B0194MC7JG  Wireless Keyboard and Mouse - Jelly Comb K025 ...
#
#                                           reviewText  \
# 0  This is my all time favorite keyboard.  It fit...
# 1  On the "cheap" side, but my biggest complaint ...
# 2  I really like this keyboard. It's bright, easy...
# 3  When I switched to Mac I fell in love with Chi...
# 4  I didn't think it would be possible with this ...
#
#                                      tokenized_words  \
# 0  [This, is, my, all, time, favorite, keyboard, ...
# 1  [On, the, cheap, side, but, my, biggest, compl...
# 2  [I, really, like, this, keyboard, It, 's, brig...
# 3  [When, I, switched, to, Mac, I, fell, in, love...
# 4  [I, did, n't, think, it, would, be, possible, ...
#
#                                     normalized_words
# 0  [time, favorite, keyboard, fits, hands, finger...
# 1  [cheap, biggest, complaint, slides, rubber, gr...
# 2  [like, keyboard, bright, easy, read, plugs, us...
# 3  [switched, mac, fell, love, chiclet, keys, swi...
# 4  [think, possible, set, ve, day, desktop, compu...

# %%
# Overall Sentiment Score
from textblob import TextBlob

df_agg['sentiment'] = float(0)
for index, row in df_agg.iterrows():
    obj = TextBlob(' '.join(df_agg['normalized_words'][index]))
    sentiment = obj.sentiment.polarity
    df_agg['sentiment'][index] = sentiment
df_senti = df_agg[['asin', 'sentiment']].sort_values('sentiment', ascending=False)
df_senti
# Out:
#          asin  sentiment
# 1  B00E4TOWR0   0.236239
# 4  B0194MC7JG   0.212755
# 2  B00I0S6SK0   0.200471
# 3  B00LSGKEC4   0.186009
# 0  B000A6PPOK   0.173015

# %%
df_sample['tokenized_words'] = df_sample['reviewText'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
df_sample['normalized_words'] = df_sample['tokenized_words'].apply(lambda x: lucem_illud_2020.normalizeTokens(x, lemma=False))
df_sample.head()
# Out:
#       Unnamed: 0        asin  \
# 5168        5168  B0194MC7JG
# 5169        5169  B0194MC7JG
# 5170        5170  B0194MC7JG
# 5171        5171  B0194MC7JG
# 5172        5172  B0194MC7JG
#
#                                                   title  overall vote  \
# 5168  Wireless Keyboard and Mouse - Jelly Comb K025 ...      5.0   16
# 5169  Wireless Keyboard and Mouse - Jelly Comb K025 ...      5.0  NaN
# 5170  Wireless Keyboard and Mouse - Jelly Comb K025 ...      2.0  NaN
# 5171  Wireless Keyboard and Mouse - Jelly Comb K025 ...      4.0  NaN
# 5172  Wireless Keyboard and Mouse - Jelly Comb K025 ...      3.0  NaN
#
#       verified   reviewTime      reviewerID                            style  \
# 5168     False  01 22, 2016  A34KGD6ZYDDVT0            {'Color:': ' Yellow'}
# 5169     False  01 19, 2016  A2YXQMZ32BY8XH            {'Color:': ' Yellow'}
# 5170      True  07 24, 2018  A286VUZ1TBV0VF  {'Color:': ' Black and Yellow'}
# 5171      True  07 22, 2018  A2B425NY1IZKXS            {'Color:': ' Yellow'}
# 5172      True   07 4, 2018  A1RD4GL359K9TD  {'Color:': ' Black and Yellow'}
#
#          reviewerName                                         reviewText  \
# 5168   ChalmondFashew  I didn't think it would be possible with this ...
# 5169           IAMM3Z  I work remotely and occasionally need to trave...
# 5170  MJS Marietta GA  Setup was easy.  Do not like the placement of ...
# 5171    ShoeLover9989  The yellow one is not whisper quite like the g...
# 5172           jx yao          Need extra force for an angled key press.
#
#                                                 summary  unixReviewTime  \
# 5168  Loving this set. Works flawlessly on my Linux ...      1453420800
# 5169             Truly is a softer & quieter experience      1453161600
# 5170                          Did not deliver for me...      1532390400
# 5171  The yellow trimmed design is not whisper quiet...      1532217600
# 5172                                     Keys too stiff      1530662400
#
#                                                   image  \
# 5168  ['https://images-na.ssl-images-amazon.com/imag...
# 5169  ['https://images-na.ssl-images-amazon.com/imag...
# 5170                                                NaN
# 5171                                                NaN
# 5172                                                NaN
#
#                                         tokenized_words  \
# 5168  [I, did, n't, think, it, would, be, possible, ...
# 5169  [I, work, remotely, and, occasionally, need, t...
# 5170  [Setup, was, easy, Do, not, like, the, placeme...
# 5171  [The, yellow, one, is, not, whisper, quite, li...
# 5172  [Need, extra, force, for, an, angled, key, press]
#
#                                        normalized_words
# 5168  [think, possible, set, ve, day, desktop, compu...
# 5169  [work, remotely, occasionally, need, travel, o...
# 5170  [setup, easy, like, placement, page, control, ...
# 5171  [yellow, whisper, like, green, ordered, read, ...
# 5172           [need, extra, force, angled, key, press]

# %%
# Calculating Sentiment for each review
df_sample['sentiment'] = float(0)
for index, row in df_sample.iterrows():
    obj = TextBlob(' '.join(df_sample['normalized_words'][index]))
    sentiment = obj.sentiment.polarity
    df_sample['sentiment'][index] = sentiment
df_senti_2 = df_sample[['asin', 'sentiment']]
df_senti_2 = df_senti_2.groupby('asin').mean().sort_values('sentiment', ascending=False)
df_senti_2
# Out:
#             sentiment
# asin
# B00E4TOWR0   0.312268
# B0194MC7JG   0.294846
# B00I0S6SK0   0.282457
# B00LSGKEC4   0.247456
# B000A6PPOK   0.244077

# %% [markdown]
# These two sentimental analysis are consistent with each other, with the same product of highest and lowest sentiment scores in both two analysis.

# %% [markdown]
# ## d. Network Analysis and topic extraction

# %%
df_meta['brand']
# Out:
# 0     Microsoft
# 1          Azio
# 2            HP
# 3      Redragon
# 4    Jelly Comb
# Name: brand, dtype: object

# %%
df_words_count[df_words_count['word'] == 'great']
# Out:
#      word  count
# 81  great    463

# %%
# Find keywords
# We can set the keywords just changed the list
ls_keywords = ['microsoft', 'azio', 'hp', 'red', 'jelly', 'great', 'good', 'problem', 'bad']
dool = []
for index, row in df_agg.iterrows():
    dool += df_agg['normalized_words'][index]

characters = {}
for token in dool:
    if token in ls_keywords:
        # all characters or actions start with @, so we add that to character
        if token not in characters:
            characters[token] = 0
        if token in characters:
            characters[token] += 1
characters
# Out:
# {'microsoft': 112,
#  'great': 463,
#  'good': 338,
#  'problem': 100,
#  'bad': 90,
#  'hp': 57,
#  'red': 68,
#  'azio': 18,
#  'jelly': 27}

# %%
import networkx as nx

# %%
actor_network = nx.Graph()

# %%
for character in characters:
    actor_network.add_node(character, lines_spoken= characters[character], words=[])

# %%
i = 0
all_texts = []

# %%
for token in dool:
    i += 1
    if i > len(dool):
        break
    if token in ls_keywords:
        if token in actor_network.nodes():
            j = i
            for token_ in dool[i:]:
                if token_ in ls_keywords:
                    # if both the characters exist in the graph, add a weight
                    if token_ != token and token_ in actor_network.nodes():
                        if (token, token_) not in actor_network.edges():
                            actor_network.add_edge(token, token_, weight=0)
                        if (token, token_) in actor_network.edges():
                            actor_network.edges[(token, token_)]['weight'] += 1
                    break
                j += 1
            # adding characters sentences
            actor_network.nodes[token]['words'].append(dool[i:j])
            all_texts.append(lucem_illud_2020.normalizeTokens(dool[i:j]))

# %%
nx.draw(actor_network, with_labels=True, font_weight='bold')

# %% [markdown]
# As we can see from the network analysis, keyboards and key are in the central, having huge connection with others, which matches with its huge frequency. It is interesting that compared with zagg, Microsoft has more connection with problems hhh.

# %%
dictionary = gensim.corpora.Dictionary(all_texts)
corpus = [dictionary.doc2bow(text) for text in all_texts]

# %%
gensim.corpora.MmCorpus.serialize('dool.mm', corpus)
doolcorpus = gensim.corpora.MmCorpus('dool.mm')
doollda = gensim.models.ldamodel.LdaModel(corpus=doolcorpus, id2word=dictionary, num_topics=5, alpha='auto', eta='auto')
doollda.show_topics()
# Out:
# [(0,
#   '0.050*"keyboard" + 0.031*"key" + 0.013*"work" + 0.013*"like" + 0.012*"use" + 0.010*"light" + 0.010*"love" + 0.010*"price" + 0.009*"color" + 0.008*"buy"'),
#  (1,
#   '0.050*"keyboard" + 0.049*"key" + 0.018*"work" + 0.012*"feel" + 0.011*"like" + 0.011*"use" + 0.010*"light" + 0.009*"type" + 0.008*"love" + 0.008*"color"'),
#  (2,
#   '0.012*"key" + 0.010*"work" + 0.009*"keyboard" + 0.007*"type" + 0.005*"mouse" + 0.005*"use" + 0.005*"price" + 0.005*"need" + 0.005*"rest" + 0.004*"quality"'),
#  (3,
#   '0.068*"keyboard" + 0.032*"key" + 0.014*"type" + 0.013*"work" + 0.012*"like" + 0.010*"mouse" + 0.009*"use" + 0.008*"light" + 0.007*"buy" + 0.007*"nice"'),
#  (4,
#   '0.057*"keyboard" + 0.025*"key" + 0.017*"work" + 0.013*"like" + 0.011*"feel" + 0.010*"type" + 0.010*"use" + 0.009*"light" + 0.007*"love" + 0.007*"mouse"')]

# %%
for actor in actor_network.nodes():
    actor_all_words = []
    for sent in actor_network.nodes[actor]['words']:
        for word in sent:
            actor_all_words += word
    actor_network.nodes[actor]['topic_distribution'] = doollda[dictionary.doc2bow(lucem_illud_2020.normalizeTokens(actor_all_words))]

# %%
for actor in actor_network.nodes():
    print(actor, actor_network.nodes[actor]['topic_distribution'])
# Out:
# microsoft [(1, 0.28589216), (3, 0.7140864)]
# great [(1, 0.27485603), (3, 0.72513694)]
# good [(1, 0.28248775), (3, 0.7175026)]
# problem [(1, 0.28309414), (3, 0.7168734)]
# bad [(1, 0.2766631), (3, 0.72329926)]
# hp [(1, 0.30044904), (3, 0.6994627)]
# red [(1, 0.25811645), (3, 0.74183726)]
# azio [(1, 0.281548), (3, 0.7182374)]
# jelly [(1, 0.2949672), (3, 0.70491785)]

# %%
from gensim.matutils import kullback_leibler
def convert_to_prob(bow):
    ps = []
    for topic_no, topic_prob in bow:
        ps.append(topic_prob)
    return ps

# %%
L = []
for actor_1 in actor_network.nodes():
    p = actor_network.nodes[actor_1]['topic_distribution'] 
    p = convert_to_prob(p)
    l = []
    for actor_2 in actor_network.nodes():
        q = actor_network.nodes[actor_2]['topic_distribution'] 
        q = convert_to_prob(q)
        l.append(kullback_leibler(p, q))
    L.append(l)
M = np.array(L)

# %%
fig = plt.figure()
div = pd.DataFrame(M, columns = list(actor_network.nodes()), index = list(actor_network.nodes()))
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# We can easily differ red and hp compared with other topic extraction, but hard to make a difference among other topics.
