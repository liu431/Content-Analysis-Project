# %% [markdown]
# ## Amazon Reviews
#
# Data Source: https://nijianmo.github.io/amazon/index.html
#
# This notebook takes in the zipped reviews and meta data from the Amazon review data of Electronics.
#
# Since the files are large and product characteristics vary, we will extract one popular product's information for further modeling and analysis.

# %% [markdown]
# ### Data Cleaning
#
# Json to dataframe

# %%
import pandas as pd
import gzip
import json

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('Electronics_5.json.gz')

# %%
df.head()
# Out:
#    overall vote  verified   reviewTime      reviewerID        asin  \
# 0      5.0   67      True  09 18, 1999   AAP7PPBU72QFM  0151004714
# 1      3.0    5      True  10 23, 2013  A2E168DTVGE6SV  0151004714
# 2      5.0    4     False   09 2, 2008  A1ER5AYS3FQ9O3  0151004714
# 3      5.0   13     False   09 4, 2000  A1T17LMQABMBN5  0151004714
# 4      3.0    8      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
#
#                             style      reviewerName  \
# 0       {'Format:': ' Hardcover'}      D. C. Carrad
# 1  {'Format:': ' Kindle Edition'}               Evy
# 2       {'Format:': ' Paperback'}             Kcorn
# 3       {'Format:': ' Hardcover'}   Caf Girl Writes
# 4       {'Format:': ' Hardcover'}  W. Shane Schmidt
#
#                                           reviewText  \
# 0  This is the best novel I have read in 2 or 3 y...
# 1  Pages and pages of introspection, in the style...
# 2  This is the kind of novel to read when you hav...
# 3  What gorgeous language! What an incredible wri...
# 4  I was taken in by reviews that compared this b...
#
#                                              summary  unixReviewTime image
# 0                                     A star is born       937612800   NaN
# 1                    A stream of consciousness novel      1382486400   NaN
# 2  I'm a huge fan of the author and this one did ...      1220313600   NaN
# 3          The most beautiful book I have ever read!       968025600   NaN
# 4                        A dissenting view--In part.       949622400   NaN

# %%
df.shape
# Out:
# (6739590, 12)

# %% [markdown]
# ### Aggregate with Metadata

# %% [markdown]
# #### Group reviews data by products

# %% [markdown]
# asin: Amazon Standard Identification Number

# %%
tbl = df.groupby('asin').agg({'overall':'count'})
tbl = tbl.sort_values(by = ['overall'], ascending = False)
tbl['asin'] = tbl.index
tbl = tbl.rename_axis("ID")
tbl
# Out:
#             overall        asin
# ID
# B003L1ZYYW     8617  B003L1ZYYW
# B0019HL8Q8     8160  B0019HL8Q8
# B0019EHU8G     7777  B0019EHU8G
# B0015DYMVO     7380  B0015DYMVO
# B000VS4HDM     6802  B000VS4HDM
# ...             ...         ...
# B000YJAWUA        1  B000YJAWUA
# B0013MYX8E        1  B0013MYX8E
# B000WGS5B8        1  B000WGS5B8
# B00166G6EG        1  B00166G6EG
# B0013MYX9S        1  B0013MYX9S
#
# [160052 rows x 2 columns]

# %% [markdown]
# #### Read in metadata and merge with aggregated review data

# %%
# read in meta data and inner merge with review data by asin
meta = pd.read_csv('meta.csv')
new = tbl.merge(meta, on = 'asin', how = 'inner')
# Out:
# C:\Users\lliu9\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new.columns
# Out:
# Index(['overall', 'asin', 'Unnamed: 0', 'category', 'description', 'title',
#        'image', 'brand', 'feature', 'rank', 'main_cat', 'date', 'price',
#        'also_buy', 'also_view', 'similar_item', 'tech1', 'tech2', 'details',
#        'fit'],
#       dtype='object')

# %% [markdown]
# #### Exploratory playground

# %%
def keep_recent(new):
    '''The function returns whether the product is released after 2016.'''
    try:
        if int(new['date'][-4:]) > 2016:
            return 1
        else:
            return 0
    except:
        return 0
    
new['newitem'] = new.apply(keep_recent, axis = 1)

# %%
sim_df = new[new['newitem'] == 1][['asin', 'title', 'overall', 'brand']]

# %%
sim_df.head(10)
# Out:
#            asin                                              title  overall  \
# 19   B00BP5KOPA  Logitech MK270 Wireless Keyboard and Mouse Com...     4625
# 26   B001TH7GUU  AmazonBasics USB 2.0 Extension Cable - A-Male ...     4503
# 36   B009D79VH4  Transcend USB 3.0 SDHC / SDXC / microSDHC / SD...     3747
# 48   B001XURP8Q  Sandisk Cruzer 32GB USB 32 GB Flash Drive, Bla...     3166
# 51   B004OVECU0  Logitech Harmony 650 Infrared All in One Remot...     3132
# 61   B001TH7GSW  AmazonBasics Digital Optical Audio Toslink Cab...     3016
# 75   B00APCMMEK  Transcend 16GB MicroSDHC Class10 UHS-1 Memory ...     2848
# 89   B000WU2LXC  ARCTIC MX-2 - Thermal Compound Paste, Carbon B...     2586
# 92   B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000     2567
# 102  B00DSUTX3O  WD Black 750GB Performance Mobile Hard Disk Dr...     2442
#
#                brand
# 19          Logitech
# 26      AmazonBasics
# 36         Transcend
# 48           SanDisk
# 51          Logitech
# 61      AmazonBasics
# 75         Transcend
# 89            ARCTIC
# 92         Microsoft
# 102  Western Digital

# %% [markdown]
# ##### Explore different brands

# %%
# Amazon products
sim_df[sim_df['brand']=='Amazon'].head()
# Out:
# Empty DataFrame
# Columns: [asin, title, overall, brand]
# Index: []

# %%
# Apple products
sim_df[sim_df['brand']=='Apple'].head()
# Out:
#              asin                                              title  overall  \
# 2913   B00UGBMRQ8  Apple MacBook Pro 15" Core i7 2.8GHz Retina (M...      349
# 4039   B0096VDM8G  Apple MacBook Pro 15-Inch Laptop with Retina D...      269
# 10007  B00B3Y4U4E  Apple MD862ZM/A Thunderbolt Cable - 0.5 M (NEW...      126
# 14257  B0186RZAWQ             Apple Smart Keyboard for iPad Pro 12.9       92
# 18190  B01H29JY62  Apple Magic Keyboard (Wireless, Rechargable) (...       73
#
#        brand
# 2913   Apple
# 4039   Apple
# 10007  Apple
# 14257  Apple
# 18190  Apple

# %%
sim_df[sim_df['brand']=='Xiaomi'].head()
# Out:
# Empty DataFrame
# Columns: [asin, title, overall, brand]
# Index: []

# %%
sim_df[sim_df['brand']=='Huawei'].head()
# Out:
# Empty DataFrame
# Columns: [asin, title, overall, brand]
# Index: []

# %%
sim_df[sim_df['brand']=='Lenovo'].head()
# Out:
#              asin                                              title  overall  \
# 15365  B00G6T8EK2  Original ThinkPad Pro Dock ( 40A10090US ) With...       86
# 19903  B00C32FWJC  ThinkPad Compact Bluetooth Keyboard with Track...       66
# 34982  B00009YUPY             Lenovo 06P4069 Optical USB Wheel Mouse       37
# 34983  B00009YUPY             Lenovo 06P4069 Optical USB Wheel Mouse       37
# 36251  B009ZN8U14   Lenovo Tiny VESA System Mounting Bracket 0B47374       35
#
#         brand
# 15365  Lenovo
# 19903  Lenovo
# 34982  Lenovo
# 34983  Lenovo
# 36251  Lenovo

# %% [markdown]
# #### Explore different products

# %%
sim_df[sim_df['title'].str.contains("camera",na = False)].head()
# Out:
#               asin                                              title  \
# 13174   B001TKRLPC  Olympus Water Ready Adjustable Strap for water...
# 45141   B001LZ5HDI  Waterproof Case | Pelican 1060 Micro Case - fo...
# 96151   B00NB1KDH0  Ashanks 0.5-3KG Pro Handheld Stabilizer/ Mini ...
# 149022  B01H4OP7Y8  Pixel Vertax D18 battery grip for Nikon D850 c...
# 166021  B0186EQ1MW                  Vsafe home HD security camera NEW
#
#         overall    brand
# 13174        99  Olympus
# 45141        27   PELICA
# 96151        10  ASHANKS
# 149022        5    PIXEL
# 166021        5    Vsafe

# %%
sim_df[sim_df['title'].str.contains("MacBook",na = False)].head()
# Out:
#             asin                                              title  overall  \
# 621   B00NH12YN0  USB Type C Cable AoLiPlus 6ft LED USB C Cable ...      958
# 1630  B00D9UTZWW  iBenzer MacBook Air 11 Inch Case, Soft Touch H...      523
# 2913  B00UGBMRQ8  Apple MacBook Pro 15" Core i7 2.8GHz Retina (M...      349
# 4039  B0096VDM8G  Apple MacBook Pro 15-Inch Laptop with Retina D...      269
# 6592  B011A286IO  MacBook Air 13 Inch Case, Lacdo Laptop Hard Ca...      180
#
#          brand
# 621   AOLIPLUS
# 1630   IBENZER
# 2913     Apple
# 4039     Apple
# 6592     Lacdo

# %%
sim_df[sim_df['title'].str.contains("Keyboard", na = False)].head(10)
# Out:
#             asin                                              title  overall  \
# 19    B00BP5KOPA  Logitech MK270 Wireless Keyboard and Mouse Com...     4625
# 92    B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000     2567
# 191   B00I0S6SK0  Azio Vision Backlit USB Keyboard with Large Pr...     1805
# 501   B00KF9IVKC  iPazzPort 3-color Backlit Wireless Mini Keyboa...     1092
# 1630  B00D9UTZWW  iBenzer MacBook Air 11 Inch Case, Soft Touch H...      523
# 1640  B00NG8EJOG  Foldable Bluetooth Keyboard, Jelly Comb B003B ...      521
# 2263  B00E4TOWR0  HP Wired USB Keyboard K1500 (Black) (H3C52AA#ABA)      418
# 2547  B00O1B59AU  ZAGG Slim Book Ultrathin Case, Hinged with Det...      387
# 2620  B00LSGKEC4  Redragon K502 Gaming Keyboard RGB LED Backlit ...      378
# 2962  B0194MC7JG  Wireless Keyboard and Mouse - Jelly Comb K025 ...      343
#
#            brand
# 19      Logitech
# 92     Microsoft
# 191         Azio
# 501    iPazzPort
# 1630     IBENZER
# 1640  Jelly Comb
# 2263          HP
# 2547        ZAGG
# 2620    Redragon
# 2962  Jelly Comb

# %%
new[new['asin']=='B00BP5KOPA'].iloc[0]
# Out:
# overall                                                      4625
# asin                                                   B00BP5KOPA
# Unnamed: 0                                                 363414
# category               ['Electronics', 'Computers & Accessories']
# description     ["The stylish Logitech MK270 Wireless Keyboard...
# title           Logitech MK270 Wireless Keyboard and Mouse Com...
# image           ['https://images-na.ssl-images-amazon.com/imag...
# brand                                                    Logitech
# feature         ['WORK FOR LONGER WITH LONG BATTERY LIFE Basic...
# rank            >#4 in Computers & Accessories (See top 100)>#...
# main_cat                                                Computers
# date                                                April 1, 2018
# price                                                      $19.99
# also_buy                                                      NaN
# also_view       ['B003VAGXZC', 'B00QXT5T3U', 'B00L1Y11D4', 'B0...
# similar_item                                                  NaN
# tech1           {'Brand Name': 'Logitech', 'Item model number'...
# tech2                                                         NaN
# details                                                       NaN
# fit                                                           NaN
# newitem                                                         1
# Name: 19, dtype: object

# %%
df[df['asin']=='B000A6PPOK']
# Out:
#          overall   vote  verified   reviewTime      reviewerID        asin  \
# 376345       5.0  1,113      True  10 18, 2005   AILCWT1IIP7ZT  B000A6PPOK
# 376346       5.0     16      True  10 12, 2005  A300T403J8526F  B000A6PPOK
# 376347       4.0     11      True   10 5, 2005   AFPGV3IQ9K691  B000A6PPOK
# 376361       5.0    NaN      True  05 15, 2018  A2FMMCFQ8702DN  B000A6PPOK
# 376362       5.0    NaN      True  05 12, 2018  A1I8WBJSZIPJE0  B000A6PPOK
# ...          ...    ...       ...          ...             ...         ...
# 379488       1.0     11     False  10 20, 2005  A3EXEZBIKEP5U3  B000A6PPOK
# 6143029      5.0    NaN      True  05 19, 2018  A3NOZ4M9D1IIR7  B000A6PPOK
# 6143030      5.0    NaN      True  05 17, 2018  A36WZAWDM2D487  B000A6PPOK
# 6143031      5.0    NaN      True  05 16, 2018   ALZ9C6MTMF20E  B000A6PPOK
# 6143032      1.0    NaN      True  05 16, 2018  A2TU423HHUTTF9  B000A6PPOK
#
#                            style      reviewerName  \
# 376345     {'Style:': ' Retail'}      Charles Chen
# 376346     {'Style:': ' Retail'}         T. Becker
# 376347     {'Style:': ' Retail'}               GDC
# 376361   {'Style:': ' Business'}        Wickenball
# 376362   {'Style:': ' Business'}         B. Stearn
# ...                          ...               ...
# 379488     {'Style:': ' Retail'}          K. HUANG
# 6143029  {'Style:': ' Business'}  john chamberlain
# 6143030    {'Style:': ' Retail'}   Amazon Customer
# 6143031  {'Style:': ' Business'}              D.J.
# 6143032  {'Style:': ' Business'}         AmazonFan
#
#                                                 reviewText  \
# 376345   As a software developer, I am literally attach...
# 376346   I've had a Natural Keyboard Pro for years, and...
# 376347   As with most Microsoft products, great hardwar...
# 376361                                            Love it.
# 376362   I've had various versions of this keyboard for...
# ...                                                    ...
# 379488   From the pictures it looks like the same, poor...
# 6143029                                               good
# 6143030  This is my second time purchasing this keyboar...
# 6143031  My favorite keyboard by far. Only issue is tha...
# 6143032  Waste of money.  Within 3 months half of the k...
#
#                                                    summary  unixReviewTime  \
# 376345                       Best Overall Keyboard to Date      1129593600
# 376346                             Best keyboard I've used      1129075200
# 376347                      Great keyboard, poor software.      1128470400
# 376361                                          Five Stars      1526342400
# 376362                                          Five Stars      1526083200
# ...                                                    ...             ...
# 379488     Real typers beware - 6 key is on the wrong side      1129766400
# 6143029                                         Five Stars      1526688000
# 6143030  The keyboard is dropped on the floor 2 to 3 ti...      1526515200
# 6143031                                  excellent product      1526428800
# 6143032  half of the keys had letters worn off in 3 mon...      1526428800
#
#         image
# 376345    NaN
# 376346    NaN
# 376347    NaN
# 376361    NaN
# 376362    NaN
# ...       ...
# 379488    NaN
# 6143029   NaN
# 6143030   NaN
# 6143031   NaN
# 6143032   NaN
#
# [2567 rows x 12 columns]

# %% [markdown]
# ### Extract Sample Data

# %%
#pd.set_option('display.max_colwidth', 1)
print(new[new['asin']=='B000A6PPOK']['title'])
# Out:
# 92    Microsoft Natural Ergonomic Keyboard 4000
# Name: title, dtype: object

# %%
new[new['asin']=='B000A6PPOK'].head()
# Out:
#     overall        asin  Unnamed: 0  \
# 92     2567  B000A6PPOK       73287
#
#                                              category description  \
# 92  ['Electronics', 'Computers & Accessories', 'Co...     ['USB']
#
#                                         title  \
# 92  Microsoft Natural Ergonomic Keyboard 4000
#
#                                                 image      brand  \
# 92  ['https://images-na.ssl-images-amazon.com/imag...  Microsoft
#
#                                               feature  \
# 92  ['Split ergonomic design encourages natural ha...
#
#                                                  rank  ...  \
# 92  ['>#222 in Computers & Accessories > Computer ...  ...
#
#                   date price  \
# 92  September 27, 2017   NaN
#
#                                              also_buy  \
# 92  ['B00FPAVUHC', 'B0043T7FXE', 'B001F42MKG', 'B0...
#
#                                             also_view  \
# 92  ['B075GZVD4T', 'B002MMY4WY', 'B00CYX26BC', 'B0...
#
#                                          similar_item tech1 tech2 details  \
# 92  [{'asin': '', 'href': '', 'name': 'Microsoft N...   NaN   NaN     NaN
#
#     fit newitem
# 92  NaN       1
#
# [1 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['overall', 'vote', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'style', 'reviewerName', 'reviewText', 'summary', 'unixReviewTime',
#        'image'],
#       dtype='object')

# %%
pdt = df[df['asin']=='B000A6PPOK']
pdt.to_csv('sample.csv')

# %% [markdown]
# ### Extract Larger Sample Data

# %%
sim_df[sim_df['title'].str.contains("Keyboard",na = False)].head()
# Out:
#             asin                                              title  overall  \
# 19    B00BP5KOPA  Logitech MK270 Wireless Keyboard and Mouse Com...     4625
# 92    B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000     2567
# 191   B00I0S6SK0  Azio Vision Backlit USB Keyboard with Large Pr...     1805
# 501   B00KF9IVKC  iPazzPort 3-color Backlit Wireless Mini Keyboa...     1092
# 1630  B00D9UTZWW  iBenzer MacBook Air 11 Inch Case, Soft Touch H...      523
#
#           brand
# 19     Logitech
# 92    Microsoft
# 191        Azio
# 501   iPazzPort
# 1630    IBENZER

# %%
pdt_large = df[df['asin']=='B00BP5KOPA']
pdt_large.to_csv('sample_large.csv')

# %% [markdown]
# ### Extract Similar Products

# %%
keyboard_top = sim_df[sim_df['title'].str.contains("Keyboard", na = False)].head(11)
keyboard_top = keyboard_top[keyboard_top['asin'].isin(['B000A6PPOK', 'B00I0S6SK0', 'B00E4TOWR0', 'B00LSGKEC4', 'B0194MC7JG'])]

# %%
keyboard_top
# Out:
#             asin                                              title  overall  \
# 92    B000A6PPOK          Microsoft Natural Ergonomic Keyboard 4000     2567
# 191   B00I0S6SK0  Azio Vision Backlit USB Keyboard with Large Pr...     1805
# 2263  B00E4TOWR0  HP Wired USB Keyboard K1500 (Black) (H3C52AA#ABA)      418
# 2620  B00LSGKEC4  Redragon K502 Gaming Keyboard RGB LED Backlit ...      378
# 2962  B0194MC7JG  Wireless Keyboard and Mouse - Jelly Comb K025 ...      343
#
#            brand
# 92     Microsoft
# 191         Azio
# 2263          HP
# 2620    Redragon
# 2962  Jelly Comb

# %%
keyboard_top['asin']
# Out:
# 92      B000A6PPOK
# 191     B00I0S6SK0
# 2263    B00E4TOWR0
# 2620    B00LSGKEC4
# 2962    B0194MC7JG
# Name: asin, dtype: object

# %%
output_meta = new[new['asin'].isin(keyboard_top['asin'])].drop(['newitem', 'Unnamed: 0'], axis=1)
output_meta.rename(columns = {'overall': 'ReviewCounts'})
output_meta.to_csv('output_meta.csv')

# %%
output_review = df[df['asin'].isin(keyboard_top['asin'])]
output_review = output_review.merge(meta[['asin', 'title']], on = 'asin', how = 'inner')

# %%
output_review.columns
# Out:
# Index(['overall', 'vote', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'style', 'reviewerName', 'reviewText', 'summary', 'unixReviewTime',
#        'image', 'title'],
#       dtype='object')

# %%
output_review = output_review[['asin', 'title', 'overall', 'vote', 'verified', 'reviewTime', 'reviewerID', 
       'style', 'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'image']]

# %%
output_review.to_csv('output_review.csv')
